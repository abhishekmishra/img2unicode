# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import ImageFont, ImageDraw, Image
import time

# %%
# Create a black image
img = np.zeros((40,500,3), np.uint8)

# Write some Text

font                   = cv2.FONT_HERSHEY_SIMPLEX
bottomLeftCornerOfText = (10,24)
fontScale              = 1
fontColor              = (255,255,255)
lineType               = 2

cv2.putText(img,'What is going on!', 
    bottomLeftCornerOfText, 
    font, 
    fontScale,
    fontColor,
    lineType)

pass

# %%
plt.imshow(img)

# %%
## Make canvas and set the color
img = np.zeros((768,1024,3),np.uint8)
b,g,r,a = 0,255,0,0

## Use cv2.FONT_HERSHEY_XXX to write English.
text = time.strftime("%Y/%m/%d %H:%M:%S %Z", time.localtime()) 
cv2.putText(img,  text, (50,50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (b,g,r), 1, cv2.LINE_AA)

## Use simsum.ttc to write Chinese.
fontpath = "./consola.ttf"     
font = ImageFont.truetype(fontpath, 32)
img_pil = Image.fromarray(img)
draw = ImageDraw.Draw(img_pil)

str_to_draw = ""
for c in range(500, 1500):
    if c%50 == 0:
        str_to_draw += '\n'
    str_to_draw += chr(c)

draw.text((50, 100),  str_to_draw, font = font, fill = (b, g, r, a))
img = np.array(img_pil)

plt.figure(figsize = (20,20))
plt.imshow(img)

# %%
chr(2040)
# Out:
# '߸'
